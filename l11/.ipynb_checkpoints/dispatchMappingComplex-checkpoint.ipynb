# %%
import os
import re
from pprint import pprint
import pandas
import numpy
import matplotlib.pyplot as plt

pandas.set_option("display.max_colwidth", 50)

# %%
dispatchFile = "entities.csv"
dispatch = pandas.read_csv(dispatchFile, sep="\t", header=0)

# %% [markdown]
# Let's do some minor modification: add a column with all dates of each month changed to 1 (we can use that to aggregate our data into months)

# %%
dispatch["month"] = [re.sub("-\d\d$", "-01", str(i)) for i in dispatch["date"]]
# convert into date format
dispatch["month"] = pandas.to_datetime(dispatch["month"], format="%Y-%m-%d")
dispatch["date"] = pandas.to_datetime(dispatch["date"], format="%Y-%m-%d")

# reorder columns
dispatch = dispatch[["itemID", "month", "date", "itemType", "itemUnified", "itemId"]]

# %%
dispatch
# Out:
#                         itemID      month       date   itemType  \
# 0       1864-04-28_article_001 1864-04-01 1864-04-28  placename
# 1       1864-04-28_article_002 1864-04-01 1864-04-28  placename
# 2       1864-04-28_article_002 1864-04-01 1864-04-28  placename
# 3       1864-04-28_article_002 1864-04-01 1864-04-28   persname
# 4       1864-04-28_article_002 1864-04-01 1864-04-28   persname
# ...                        ...        ...        ...        ...
# 989392  1864-03-31_article_169 1864-03-01 1864-03-31   persname
# 989393  1864-03-31_article_170 1864-03-01 1864-03-31   persname
# 989394  1864-03-31_article_170 1864-03-01 1864-03-31  placename
# 989395  1864-03-31_article_170 1864-03-01 1864-03-31   persname
# 989396  1864-03-31_article_170 1864-03-01 1864-03-31   persname
#
#                                  itemUnified         itemId
# 0             gordonsville, orange, virginia    tgn,2111971
# 1       plymouth, washington, north carolina    tgn,2076159
# 2       plymouth, washington, north carolina    tgn,2076159
# 3              wessels,brigadier-general,,,,  wessels,h.,w.
# 4                               lincoln,,,,,        lincoln
# ...                                      ...            ...
# 989392                         hunt,,chas,,,      hunt,chas
# 989393                            davis,,,,,    davis,waddy
# 989394    albemarle, virginia, united states    tgn,2002137
# 989395                             cook,,,,,           cook
# 989396                        turner,,geo,,,         turner
#
# [989397 rows x 6 columns]

# %% [markdown]
# We can easily count frequencies in the following manner:

# %%
dispatch_place = dispatch[dispatch["itemType"] == "placename"]

# %%
dispatch_place[["month", "itemId", "itemID"]]
# Out:
#             month       itemId                  itemID
# 0      1864-04-01  tgn,2111971  1864-04-28_article_001
# 1      1864-04-01  tgn,2076159  1864-04-28_article_002
# 2      1864-04-01  tgn,2076159  1864-04-28_article_002
# 5      1864-04-01  tgn,2076159  1864-04-28_article_002
# 7      1864-04-01  tgn,2076159  1864-04-28_article_002
# ...           ...          ...                     ...
# 989380 1864-03-01  tgn,7014404  1864-03-31_article_166
# 989381 1864-03-01  tgn,7013981  1864-03-31_article_166
# 989384 1864-03-01  tgn,7013964  1864-03-31_article_167
# 989385 1864-03-01  tgn,7013964  1864-03-31_article_167
# 989394 1864-03-01  tgn,2002137  1864-03-31_article_170
#
# [358929 rows x 3 columns]

# %%
tgnFile = "TGNOut_Coordinates.csv"
tgnData = pandas.read_csv(tgnFile, sep="\t", header=0)

# %%
tgnData.head(10)
# Out:
#         TGN_ID        LAT         LON
# 0  tgn,1000001  42.284495 -101.123047
# 1  tgn,1000002  -3.550000  -56.683000
# 2  tgn,1000003  56.200000   15.016000
# 3  tgn,1000004  43.800000   87.633000
# 4  tgn,1000006 -18.510219  139.367118
# 5  tgn,1000007 -83.843000   65.725000
# 6  tgn,1000009  17.050000  -61.800000
# 7  tgn,1000046 -17.000000  -65.000000
# 8  tgn,1000047 -10.000000  -55.000000
# 9  tgn,1000048 -60.000000  -45.000000

# %%
tgnData.columns = ["itemId", "lat", "lon"]

tgnData.head(10)
# Out:
#         itemId        lat         lon
# 0  tgn,1000001  42.284495 -101.123047
# 1  tgn,1000002  -3.550000  -56.683000
# 2  tgn,1000003  56.200000   15.016000
# 3  tgn,1000004  43.800000   87.633000
# 4  tgn,1000006 -18.510219  139.367118
# 5  tgn,1000007 -83.843000   65.725000
# 6  tgn,1000009  17.050000  -61.800000
# 7  tgn,1000046 -17.000000  -65.000000
# 8  tgn,1000047 -10.000000  -55.000000
# 9  tgn,1000048 -60.000000  -45.000000

# %%
merged = pandas.merge(dispatch_place, tgnData, on=["itemId"])

# %%
merged
# Out:
#                         itemID      month       date   itemType  \
# 0       1864-04-28_article_001 1864-04-01 1864-04-28  placename
# 1        1864-06-22_orders_130 1864-06-01 1864-06-22  placename
# 2       1862-07-25_article_013 1862-07-01 1862-07-25  placename
# 3       1862-07-25_article_013 1862-07-01 1862-07-25  placename
# 4       1862-07-17_article_003 1862-07-01 1862-07-17  placename
# ...                        ...        ...        ...        ...
# 348604  1863-06-04_article_019 1863-06-01 1863-06-04  placename
# 348605  1862-08-25_article_010 1862-08-01 1862-08-25  placename
# 348606  1862-08-25_article_010 1862-08-01 1862-08-25  placename
# 348607  1864-11-18_article_029 1864-11-01 1864-11-18  placename
# 348608  1864-03-31_article_007 1864-03-01 1864-03-31  placename
#
#                                   itemUnified       itemId      lat      lon
# 0              gordonsville, orange, virginia  tgn,2111971  38.1333 -78.1833
# 1              gordonsville, orange, virginia  tgn,2111971  38.1333 -78.1833
# 2              gordonsville, orange, virginia  tgn,2111971  38.1333 -78.1833
# 3              gordonsville, orange, virginia  tgn,2111971  38.1333 -78.1833
# 4              gordonsville, orange, virginia  tgn,2111971  38.1333 -78.1833
# ...                                       ...          ...      ...      ...
# 348604        seneca, new york, united states  tgn,1002882  42.7833 -76.8500
# 348605       mallard creek, lawrence, alabama  tgn,2489504  34.5833 -87.2167
# 348606  wards mill creek, tuscaloosa, alabama  tgn,2751076  33.3667 -87.6833
# 348607       gwinnett, georgia, united states  tgn,2000358  33.9500 -84.0500
# 348608              madison, madison, florida  tgn,2020252  30.4667 -83.4000
#
# [348609 rows x 8 columns]

# %%
dispatchTextFile = "textList.csv"
dispatchText = pandas.read_csv(dispatchTextFile, sep="\t", header=0)
dispatchText = dispatchText[["itemID", "text"]]
place_text = pandas.merge(merged, dispatchText, on=["itemID"])

# %%
place_text = place_text[["month", "itemUnified", "itemId", "lat", "lon", "text"]]
place_text = place_text.sort_values('month')
place_text = place_text.reset_index()

# %%
place_text
# Out:
#          index      month                                        itemUnified  \
# 0       221807 1860-11-01                       richmond, richmond, virginia
# 1       295981 1860-11-01                                      united states
# 2       306397 1860-11-01             charleston, charleston, south carolina
# 3       295918 1860-11-01                                             bharat
# 4       295917 1860-11-01                                             bharat
# ...        ...        ...                                                ...
# 349447    9767 1865-12-01  virginia, united states, north and central ame...
# 349448    9768 1865-12-01                                     united kingdom
# 349449    9769 1865-12-01                                            europe,
# 349450  240435 1865-12-01                       richmond, richmond, virginia
# 349451  282850 1865-12-01                                      united states
#
#              itemId      lat      lon  \
# 0       tgn,7013964  37.5500 -77.4500
# 1       tgn,7012149  38.0000 -98.0000
# 2       tgn,7013582  32.7667 -79.9167
# 3       tgn,7000198  20.0000  77.0000
# 4       tgn,7000198  20.0000  77.0000
# ...             ...      ...      ...
# 349447  tgn,7007919  37.0000 -80.0000
# 349448  tgn,7002445  53.0000  -2.0000
# 349449  tgn,1000003  56.2000  15.0160
# 349450  tgn,7013964  37.5500 -77.4500
# 349451  tgn,7012149  38.0000 -98.0000
#
#                                                      text
# 0       the undersigned have formed a copartnership fo...
# 1       lawrence s. marye, attorney at law,;;; practic...
# 2       pretty locomotives.;;; --at the dredegar works...
# 3       audacious burglary.;;; --about 3 o'clock yeste...
# 4       encouragement to agriculture.;;; we have latel...
# ...                                                   ...
# 349447  a jamestown festival.;;; we never read the acc...
# 349448  a jamestown festival.;;; we never read the acc...
# 349449  a jamestown festival.;;; we never read the acc...
# 349450  appointments.;;; --the following appointments ...
# 349451  associated press dispatches.;;; from washingto...
#
# [349452 rows x 7 columns]

# %%
var = "sherman"

dispatch_search = place_text[place_text["text"].str.contains(var)]
dispatch_search = dispatch_search.reset_index()
dispatch_search['occur'] = dispatch_search["text"].str.count(var)


#dispatch_search = dispatch_search.reset_index()
#dispatch_search = dispatch_search.groupby(dispatch_search.columns.tolist(),as_index=False).size()

#dispatch_search = dispatch_search.groupby(dispatch_search.columns.tolist(),as_index=False).size()
#aggregation = {"occur":"sum"}
#dispatch_searchs = dispatch_search.groupby(dispatch_search['month']).aggregate(aggregation)
#dispatch_search = dispatch_search.reset_index()

# %%
sherman_place = dispatch_search[dispatch_search["occur"] > 3]

# %%
sherman_place = sherman_place[["month", "itemUnified", "lat", "lon"]]
sherman_place = sherman_place.reset_index()
sherman_place = sherman_place[["month", "itemUnified", "lat", "lon"]]

# %%
sherman_place
# Out:
#           month                                 itemUnified    lat      lon
# 0    1860-12-01                                     florida  28.00 -82.0000
# 1    1860-12-01                                     alabama  33.00 -87.0000
# 2    1860-12-01                                     alabama  33.00 -87.0000
# 3    1860-12-01                                     alabama  33.00 -87.0000
# 4    1860-12-01                                     alabama  33.00 -87.0000
# ...         ...                                         ...    ...      ...
# 7234 1865-03-01    philadelphia, philadelphia, pennsylvania  39.95 -75.1500
# 7235 1865-04-01    fayetteville, cumberland, north carolina  35.05 -78.8667
# 7236 1865-04-01                  moscow, fayette, tennessee  35.05 -89.4000
# 7237 1865-04-01  united states, north and central america,   38.00 -98.0000
# 7238 1865-04-01                                     georgia  32.00 -84.0000
#
# [7239 rows x 4 columns]

# %%
sherman_place = sherman_place.groupby(sherman_place.columns.tolist(),as_index=False).size()

# %%
sherman_place
# Out:
#           month                                 itemUnified      lat      lon  \
# 0    1860-12-01                                     alabama  33.0000 -87.0000
# 1    1860-12-01                                     florida  28.0000 -82.0000
# 2    1860-12-01                                     georgia  32.0000 -84.0000
# 3    1860-12-01                                    illinois  40.0000 -89.0000
# 4    1860-12-01                                     indiana  40.0000 -86.0000
# ...         ...                                         ...      ...      ...
# 2310 1865-03-01               york, virginia, united states  37.5167 -76.7833
# 2311 1865-04-01    fayetteville, cumberland, north carolina  35.0500 -78.8667
# 2312 1865-04-01                                     georgia  32.0000 -84.0000
# 2313 1865-04-01                  moscow, fayette, tennessee  35.0500 -89.4000
# 2314 1865-04-01  united states, north and central america,   38.0000 -98.0000
#
#       size
# 0        5
# 1        1
# 2        2
# 3        3
# 4        1
# ...    ...
# 2310     1
# 2311     1
# 2312     1
# 2313     1
# 2314     1
#
# [2315 rows x 5 columns]

# %%
sherman_place['month'] = sherman_place['month'].dt.strftime('%Y-%m')

# %%
sherman_place
# Out:
#          month                         itemUnified        lat       lon  size
# 0      1860-11        aberdeen, aberdeen, scotland  57.133333   -2.1000     1
# 1      1860-11      abingdon, washington, virginia  36.700000  -81.9667     1
# 2      1860-11         accomac, accomack, virginia  37.716700  -75.6500    10
# 3      1860-11             acme, dickinson, kansas  38.833300  -97.2500     9
# 4      1860-11  adams valley, la crosse, wisconsin  43.966700  -91.0000    37
# ...        ...                                 ...        ...       ...   ...
# 47396  1865-12       york, virginia, united states  37.233300  -76.5500     2
# 47397  1865-12       york, virginia, united states  37.516700  -76.7833     1
# 47398  1865-12            york, york, pennsylvania  39.950000  -76.7167     2
# 47399  1865-12                             yucatan  20.833333  -89.0000     1
# 47400  1865-12                            zhonghua  35.000000  105.0000     9
#
# [47401 rows x 5 columns]
